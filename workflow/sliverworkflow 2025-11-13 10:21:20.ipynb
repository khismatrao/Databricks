-- %%
CREATE SCHEMA IF NOT EXISTS catalogworkflowdemo.silver
     MANAGED LOCATION 'abfss://workflowdemo@pakaru27sa.dfs.core.windows.net/silver';

-- %%
DROP TABLE IF EXISTS catalogworkflowdemo.silver.companies;

CREATE TABLE catalogworkflowdemo.silver.companies
  (company_id   BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
   company_name STRING,
   founded_date DATE,
   founded_year INT GENERATED ALWAYS AS (YEAR(founded_date)),
   country      STRING);

INSERT INTO catalogworkflowdemo.silver.companies 
(company_name, founded_date, country)
SELECT company_name,
       founded_date,
       country
  FROM catalogworkflowdemo.bronze.companies;
