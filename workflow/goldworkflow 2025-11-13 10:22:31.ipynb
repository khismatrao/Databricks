-- %%
CREATE SCHEMA IF NOT EXISTS catalogworkflowdemo.gold
     MANAGED LOCATION 'abfss://workflowdemo@pakaru27sa.dfs.core.windows.net/gold';

-- %%
DROP TABLE IF EXISTS catalogworkflowdemo.gold.company_summary;

CREATE TABLE catalogworkflowdemo.gold.company_summary
AS
SELECT country,
       COUNT(*) AS num_companies
  FROM catalogworkflowdemo.silver.companies
 GROUP BY country;
