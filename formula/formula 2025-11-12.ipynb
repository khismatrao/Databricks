-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `formula_table`
    URL 'abfss://formula@pakaru27sa.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL parku27)
    COMMENT 'External Location for formulaPurposes'

-- %%
%fs ls 'abfss://formula@pakaru27sa.dfs.core.windows.net/ishwarilanding'

-- %%
%sql
CREATE CATALOG ishwariformulabox
MANAGED LOCATION 'abfss://formula@pakaru27sa.dfs.core.windows.net/';

-- %%
%sql
USE CATALOG ishwariformulabox;
CREATE SCHEMA IF NOT EXISTS schemalanding
     MANAGED LOCATION 'abfss://formula@pakaru27sa.dfs.core.windows.net/';

-- %%
%sql
USE CATALOG ishwariformulabox;
CREATE SCHEMA IF NOT EXISTS schemalakehouse
     MANAGED LOCATION 'abfss://formula@pakaru27sa.dfs.core.windows.net/';

-- %%
%sql
USE CATALOG ishwariformulabox;
USE SCHEMA schemalanding;


CREATE EXTERNAL VOLUME IF NOT EXISTS volume2
    LOCATION 'abfss://formula@pakaru27sa.dfs.core.windows.net/ishwarilanding/operational/'
