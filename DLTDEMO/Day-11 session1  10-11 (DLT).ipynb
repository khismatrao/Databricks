# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `delta_live_tables`
    URL 'abfss://circuitbox@pakaru27sa.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL parku27)
    COMMENT 'External Location for circuitboxPurposes'

# %%
# %fs ls 'abfss://circuitbox@pakaru27sa.dfs.core.windows.net/Landing'

# %%
# %sql
CREATE CATALOG ishwaricircuitbox
MANAGED LOCATION 'abfss://circuitbox@pakaru27sa.dfs.core.windows.net/';

# %%
# %sql
USE CATALOG ishwaricircuitbox;
CREATE SCHEMA IF NOT EXISTS schemalanding
     MANAGED LOCATION 'abfss://circuitbox@pakaru27sa.dfs.core.windows.net/';

# %%
# %sql
USE CATALOG ishwaricircuitbox;
CREATE SCHEMA IF NOT EXISTS schemalakehouse
     MANAGED LOCATION 'abfss://circuitbox@pakaru27sa.dfs.core.windows.net/';

# %%
# %sql
USE CATALOG ishwaricircuitbox;
USE SCHEMA schemalanding;

CREATE EXTERNAL VOLUME IF NOT EXISTS volume1
    LOCATION 'abfss://circuitbox@pakaru27sa.dfs.core.windows.net/Landing/Operational_data/'

# %%
# %sql
drop volume if exists volume1;

# %%
# %sql
USE CATALOG ishwaricircuitbox;
USE SCHEMA schemalanding;


CREATE EXTERNAL VOLUME IF NOT EXISTS volume2
    LOCATION 'abfss://circuitbox@pakaru27sa.dfs.core.windows.net/Landing/operational data/'
