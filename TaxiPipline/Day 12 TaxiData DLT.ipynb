-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `delta_taxi_tables`
    URL 'abfss://taxidlt@pakaru27sa.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL parku27)
    COMMENT 'External Location for taxidltPurposes'

-- %%
%fs ls 'abfss://taxidlt@pakaru27sa.dfs.core.windows.net/landing'

-- %%
%sql
CREATE CATALOG ishwaritaxi
MANAGED LOCATION 'abfss://taxidlt@pakaru27sa.dfs.core.windows.net/';

-- %%
%sql
USE CATALOG ishwaritaxi;
CREATE SCHEMA IF NOT EXISTS taxilanding
     MANAGED LOCATION 'abfss://taxidlt@pakaru27sa.dfs.core.windows.net/';

-- %%
%sql
USE CATALOG ishwaritaxi;
CREATE SCHEMA IF NOT EXISTS taxilakehouse
     MANAGED LOCATION 'abfss://taxidlt@pakaru27sa.dfs.core.windows.net/';

-- %%
%sql
USE CATALOG ishwaritaxi;
USE SCHEMA taxilanding;

CREATE EXTERNAL VOLUME IF NOT EXISTS volume2
    LOCATION 'abfss://taxidlt@pakaru27sa.dfs.core.windows.net/landing/operationalData/yellowtaxi'

-- %%
drop volume if exists volume1
